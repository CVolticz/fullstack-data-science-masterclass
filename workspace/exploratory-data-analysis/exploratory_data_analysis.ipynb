# %% [markdown]
# # Exploratory Data Analysis
# Exploratory Data Analysis (EDA) is the most important step in your Data Science career. The goal of EDA is to learn as much important information as possible from the dataset you obtained to leverage it to build advance machine learning models and your findings to your stakeholders. To get ourselves comfortable with the EDA process, we'll be working with datasets from three projects:
#
# 1. Employee Salary \
#   a. salary.csv
#
# 2. Medical Insurance \
#   a. insurance.csv
#
# 3. Retail Sales \
#   a. Feature_data_set.csv \
#   b. sales_data_set.csv \
#   c. stores_data_set.csv

# %% [markdown]
# # Import Libraries
# - pandas: Use to perform small to medium dataframe manipulation
# - numpy: Use to perform array arithmetic
# - matplolib: Use for plotting
# - seaborn: Use for plotting and styling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Project #1: Employee Salary
# Let's read in the dataframe "salary.csv" and perform the standard EDA process

# %%
# Read in the data of interest and view the top 5 rows of data
salary_df = pd.read_csv('./data/salary.csv')
salary_df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# ### MINI CHALLENGE
#  - Use head and tail methods to print the first and last 7 rows of the dataframe
#  - Try to find the maximum salary value in the dataframe

# %%
# head and tail and min of the df
top_7 = #IMPLEMENT ME
bottom_7 = #IMPLEMENT ME
max_value = # INPLEMENT ME

print(f"head: {top_7}")
print(f"tail: {bottom_7}")
print(f"max salary: {max_value}")

# %% [markdown]
# ## DataFrame Summary Statistics
#
# #### Info Method
# One of the common error encounter in Data Science is typing error. Essentially, data always come in multiple type. However, the dataset we received do not always come with the desired typing for each field. This could be due to type conversion between computers or the data wasn't typed correctly in the database. Nevertheless, we can quickly find out what the type for each field in our dataset is using the build-in info method.
#
# #### Describe Method
# Describe is another powerful high level method. In earlier challenge, you were asked to print out the max value of salary for one column of the dataframe. If you're looking for doing this on more than one dataframe, you can use the build-in describe method to obtain this information (along with other quick statitics like min, mean, count, standard deviation, etc.) quickly.
#
# NOTE: While describe works for numerical information, you will not get any meaningful information using describe on a text based column

# %%
# Check the dataframe info
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 688.0 bytes

# %%
# describe the dataframe columns
salary_df.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %% [markdown]
# ### MINI CHALLENGE
#  - What are the number of years of experience corresponding to employees with minimum and maximim salaries?

# %%
min_max_salary = #IMPLEMENT ME
min_max_salary

# %% [markdown]
# ## Plotting
# Plotting provide visual aids on the current dataset you are working with. There are many different plot, each with different function and convey a different message. Let's examine some plots regarding the current dataset

# %%
salary_df.hist(bins = 30, figsize = (20,10), color = 'r')
# Out:
# array([[<Axes: title={'center': 'YearsExperience'}>,
#         <Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
# plot pairplot
sns.pairplot(salary_df)

# %%
corr_matrix = salary_df.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()
